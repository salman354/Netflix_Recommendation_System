# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('Netflix Dataset Latest 2021.xlsx')

# %%
df
# Out:
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre  \
# 0     Crime, Drama, Fantasy, Horror, Romance
# 1                                     Comedy
# 2                            Comedy, Romance
# 3                                      Drama
# 4                                      Drama
# ...                                      ...
# 9420                Comedy, Fantasy, Romance
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9425 non-null   object
#  1   Genre                  9400 non-null   object
#  2   Tags                   9389 non-null   object
#  3   Languages              9266 non-null   object
#  4   Series or Movie        9425 non-null   object
#  5   Hidden Gem Score       9415 non-null   float64
#  6   Country Availability   9414 non-null   object
#  7   Runtime                9424 non-null   object
#  8   Director               7120 non-null   object
#  9   Writer                 7615 non-null   object
#  10  Actors                 9314 non-null   object
#  11  View Rating            6827 non-null   object
#  12  IMDb Score             9417 non-null   float64
#  13  Rotten Tomatoes Score  5445 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Title                       0
# Genre                      25
# Tags                       36
# Languages                 159
# Series or Movie             0
# Hidden Gem Score           10
# Country Availability       11
# Runtime                     1
# Director                 2305
# Writer                   1810
# Actors                    111
# View Rating              2598
# IMDb Score                  8
# Rotten Tomatoes Score    3980
# Metacritic Score         5343
# Awards Received          4199
# Awards Nominated For     3049
# Boxoffice                5671
# Release Date              208
# Netflix Release Date        0
# Production House         5032
# Netflix Link                0
# IMDb Link                 324
# Summary                     5
# IMDb Votes                 10
# Image                       0
# Poster                    938
# TMDb Trailer                0
# Trailer Site                1
# dtype: int64

# %%
df.describe()
# Out:
#        Hidden Gem Score   IMDb Score  Rotten Tomatoes Score  Metacritic Score  \
# count       9415.000000  9417.000000            5445.000000       4082.000000
# mean           5.540733     6.955517              64.691276         58.113425
# std            2.447462     0.899681              25.269466         17.143187
# min            0.600000     1.600000               0.000000          6.000000
# 25%            3.400000     6.500000              49.000000         46.000000
# 50%            5.300000     7.000000              70.000000         59.000000
# 75%            8.100000     7.500000              85.000000         71.000000
# max            9.800000     9.700000             100.000000        100.000000
#
#        Awards Received  Awards Nominated For     Boxoffice    IMDb Votes
# count      5226.000000           6376.000000  3.754000e+03  9.415000e+03
# mean          9.735936             16.035602  4.845788e+07  6.014725e+04
# ...

# %%
df=df.drop(columns=['Netflix Link','IMDb Link','Summary','Image','Poster','TMDb Trailer','Trailer Site'])

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'IMDb Votes'],
#       dtype='object')

# %%
max_ratings=df['IMDb Score'].max()

# %%
df.loc[df['IMDb Score']==max_ratings]
# Out:
#            Title               Genre  \
# 187  No Festival  Documentary, Music
#
#                                                   Tags Languages  \
# 187  Music & Musicals,Music & Concert Documentaries...  Romanian
#
#     Series or Movie  Hidden Gem Score Country Availability   Runtime  \
# 187           Movie               9.8              Romania  1-2 hour
#
#         Director        Writer  ... IMDb Score Rotten Tomatoes Score  \
# 187  Dorin Marcu  Andy Daniluc  ...        9.7                   NaN
#
#      Metacritic Score  Awards Received  Awards Nominated For  Boxoffice  \
# 187               NaN              NaN                   NaN        NaN
#
#      Release Date  Netflix Release Date Production House IMDb Votes
# 187    2020-07-15            2021-01-24              NaN       49.0
#
# [1 rows x 22 columns]

# %%
hindi_df=df.loc[df['Languages']=='Hindi']

# %%
a=hindi_df[['Title','IMDb Score']].groupby(['Title','IMDb Score']).size().reset_index()

# %%
a
# Out:
#                         Title  IMDb Score  0
# 0                 A Wednesday         8.1  1
# 1    ABCD: Any Body Can Dance         6.3  1
# 2                    AK vs AK         7.0  1
# 3                       Aamir         7.7  1
# 4                   Agneepath         7.7  1
# ..                        ...         ... ..
# 177      Welcome to Sajjanpur         6.9  1
# 178            Well Done Abba         7.3  1
# 179                Yeh Ballet         7.6  1
# 180                      Zero         5.4  1
# 181      ​​Kuch Bheege Alfaaz         7.5  1
#
# [182 rows x 3 columns]

# %%
a.sort_values(by='IMDb Score',ascending=False).head(10)
# Out:
#                              Title  IMDb Score  0
# 145               Regiment Diaries         9.1  1
# 140  Raja Rasoi Aur Anya Kahaniyan         9.0  1
# 33                 College Romance         8.9  1
# 24                    Black Friday         8.5  1
# 161               Taare Zameen Par         8.4  1
# 36                   Dharmakshetra         8.2  1
# 143                Rang De Basanti         8.2  1
# 122               Paan Singh Tomar         8.2  1
# 12                      Article 15         8.2  1
# 64      Gangs of Wasseypur: Part 1         8.2  1

# %%
a.value_counts()
# Out:
# Title                        IMDb Score  0
# A Wednesday                  8.1         1    1
# Mighty Little Bheem: Diwali  7.0         1    1
# Mom                          7.3         1    1
# Mumbai Meri Jaan             7.7         1    1
# Muzaffarnagar Baaqi Hai      6.9         1    1
#                                              ..
# Gabbar Is Back               7.1         1    1
# Gangaajal                    7.8         1    1
# Gangs of Wasseypur: Part 1   8.2         1    1
# Gangs of Wasseypur: Part 2   8.2         1    1
# ​​Kuch Bheege Alfaaz         7.5         1    1
# Length: 182, dtype: int64

# %%
indian_netflix=df.loc[df['Country Availability']=='India']

# %%
b=indian_netflix[['Title','IMDb Score']].groupby(['Title','IMDb Score']).size().reset_index()

# %%
top10_indian=b.sort_values(by='IMDb Score',ascending=False).head(10)

# %%
top10_indian
# Out:
#                          Title  IMDb Score  0
# 26  Gangs of Wasseypur: Part 2         8.2  1
# 39                      Masaan         8.2  1
# 25  Gangs of Wasseypur: Part 1         8.2  1
# 38    Manjhi: The Mountain Man         8.0  1
# 57                The Lunchbox         7.8  1
# 12                      Blippi         7.8  1
# 6              Ask the Sexpert         7.6  1
# 40         Matangi/Maya/M.I.A.         7.6  1
# 34                    Loveless         7.6  1
# 54             The Kite Runner         7.6  1

# %%
best_rating=indian_netflix['IMDb Score'].max()

# %%
best_rating
# Out:
# 8.2

# %%
top_movie=indian_netflix.loc[indian_netflix['IMDb Score']==best_rating]

# %%
top_movie
# Out:
#                            Title                                   Genre  \
# 5672                      Masaan                                   Drama
# 6446  Gangs of Wasseypur: Part 2  Action, Comedy, Crime, Drama, Thriller
# 6447  Gangs of Wasseypur: Part 1  Action, Comedy, Crime, Drama, Thriller
#
#                                                    Tags Languages  \
# 5672   International Dramas,International Movies,Dramas     Hindi
# 6446  Dramas,International Action & Adventure,Epics,...     Hindi
# 6447  Action & Adventure,Crime Action & Adventure,In...     Hindi
#
#      Series or Movie  Hidden Gem Score Country Availability   Runtime  \
# 5672           Movie               4.3                India  1-2 hour
# 6446           Movie               4.5                India   > 2 hrs
# 6447           Movie               4.5                India   > 2 hrs
#
#             Director                                             Writer  ...  \
# ...
