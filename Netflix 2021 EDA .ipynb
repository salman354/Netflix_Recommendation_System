# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("Netflix Dataset Latest 2021.xlsx")

# %%
df
# Out:
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre  \
# 0     Crime, Drama, Fantasy, Horror, Romance
# 1                                     Comedy
# 2                            Comedy, Romance
# 3                                      Drama
# 4                                      Drama
# ...                                      ...
# 9420                Comedy, Fantasy, Romance
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9425 non-null   object
#  1   Genre                  9400 non-null   object
#  2   Tags                   9389 non-null   object
#  3   Languages              9266 non-null   object
#  4   Series or Movie        9425 non-null   object
#  5   Hidden Gem Score       9415 non-null   float64
#  6   Country Availability   9414 non-null   object
#  7   Runtime                9424 non-null   object
#  8   Director               7120 non-null   object
#  9   Writer                 7615 non-null   object
#  10  Actors                 9314 non-null   object
#  11  View Rating            6827 non-null   object
#  12  IMDb Score             9417 non-null   float64
#  13  Rotten Tomatoes Score  5445 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Hidden Gem Score   IMDb Score  Rotten Tomatoes Score  Metacritic Score  \
# count       9415.000000  9417.000000            5445.000000       4082.000000
# mean           5.540733     6.955517              64.691276         58.113425
# std            2.447462     0.899681              25.269466         17.143187
# min            0.600000     1.600000               0.000000          6.000000
# 25%            3.400000     6.500000              49.000000         46.000000
# 50%            5.300000     7.000000              70.000000         59.000000
# 75%            8.100000     7.500000              85.000000         71.000000
# max            9.800000     9.700000             100.000000        100.000000
#
#        Awards Received  Awards Nominated For     Boxoffice    IMDb Votes
# count      5226.000000           6376.000000  3.754000e+03  9.415000e+03
# mean          9.735936             16.035602  4.845788e+07  6.014725e+04
# ...

# %%
df.isnull().sum()
# Out:
# Title                       0
# Genre                      25
# Tags                       36
# Languages                 159
# Series or Movie             0
# Hidden Gem Score           10
# Country Availability       11
# Runtime                     1
# Director                 2305
# Writer                   1810
# Actors                    111
# View Rating              2598
# IMDb Score                  8
# Rotten Tomatoes Score    3980
# Metacritic Score         5343
# Awards Received          4199
# Awards Nominated For     3049
# Boxoffice                5671
# Release Date              208
# Netflix Release Date        0
# Production House         5032
# Netflix Link                0
# IMDb Link                 324
# Summary                     5
# IMDb Votes                 10
# Image                       0
# Poster                    938
# TMDb Trailer                0
# Trailer Site                1
# dtype: int64

# %%
df['IMDb Score'].max()
# Out:
# 9.7

# %%
df.loc[df['IMDb Score']==df['IMDb Score'].max()]
# Out:
#            Title               Genre  \
# 187  No Festival  Documentary, Music
#
#                                                   Tags Languages  \
# 187  Music & Musicals,Music & Concert Documentaries...  Romanian
#
#     Series or Movie  Hidden Gem Score Country Availability   Runtime  \
# 187           Movie               9.8              Romania  1-2 hour
#
#         Director        Writer  ... Netflix Release Date Production House  \
# 187  Dorin Marcu  Andy Daniluc  ...           2021-01-24              NaN
#
#                                Netflix Link  \
# 187  https://www.netflix.com/watch/81351804
#
#                                  IMDb Link  \
# 187  https://www.imdb.com/title/tt12798264
#
#                                                Summary  IMDb Votes  \
# 187  Due to a pandemic, the Electric Castle music f...        49.0
#
#                                                  Image  \
# 187  https://occ-0-3017-3466.1.nflxso.net/dnm/api/v...
#
# ...

# %%
df=df.drop(columns=['Netflix Link','IMDb Link','TMDb Trailer','Trailer Site','Image','Poster'])

# %%
countries=df['Country Availability'].value_counts()

# %%
hindi_content=df.loc[df['Languages']=='Hindi']

# %%
hindi_content
# Out:
#                       Title                                    Genre  \
# 83           Eeb Allay Ooo!                            Comedy, Drama
# 93     Awara Paagal Deewana   Action, Comedy, Crime, Drama, Thriller
# 126   Dont be the First one                  Action, Crime, Thriller
# 276               Gangaajal                     Action, Crime, Drama
# 277            BluffMaster!  Comedy, Crime, Drama, Romance, Thriller
# ...                     ...                                      ...
# 7969                Fashion                                    Drama
# 7983     Ek Main Aur Ekk Tu                   Comedy, Drama, Romance
# 8021                   Boss             Action, Comedy, Crime, Drama
# 8079             Special 26                   Crime, Drama, Thriller
# 8790                   I Am           Documentary, Biography, Family
#
#                                                    Tags Languages  \
# 83    Dark Comedies,Social Issue Dramas,Dramas,Comed...     Hindi
# ...

# %%
hindi_content.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Summary', 'IMDb Votes'],
#       dtype='object')

# %%
best_ratings=hindi_content['IMDb Score'].max()
best_ratings
# Out:
# 9.1

# %%
hindi_content.loc[hindi_content['IMDb Score']==best_ratings]
# Out:
#                  Title        Genre  \
# 2551  Regiment Diaries  Documentary
#
#                                                    Tags Languages  \
# 2551  Documentaries,Military Documentaries,Indian TV...     Hindi
#
#      Series or Movie  Hidden Gem Score  \
# 2551          Series               9.5
#
#                                    Country Availability       Runtime  \
# 2551  Australia,Russia,Singapore,India,Lithuania,Rom...  < 30 minutes
#
#      Director Writer  ... Rotten Tomatoes Score Metacritic Score  \
# 2551      NaN    NaN  ...                   NaN              NaN
#
#       Awards Received  Awards Nominated For  Boxoffice  Release Date  \
# 2551              NaN                   NaN        NaN    2018-08-16
#
#       Netflix Release Date  Production House  \
# 2551            2019-08-01               NaN
#
#                                                 Summary IMDb Votes
# 2551  Historical footage and interviews with soldier...       50.0
#
# ...

# %%
hindi_content['Title'].value_counts().head(10)
# Out:
# Happy New Year       2
# The Violin Player    2
# Once Again           2
# Kaabil               1
# Ujala                1
# Manoranjan           1
# Phir Hera Pheri      1
# Professor            1
# Hunterrr             1
# Ishq Vishk           1
# Name: Title, dtype: int64

# %%
a=hindi_content[['Title','IMDb Score']].groupby(['Title','IMDb Score']).size().reset_index()

# %%
top_10_hindi=a.sort_values(by='IMDb Score',ascending=False).head(10)

# %%
top_10_hindi
# Out:
#                              Title  IMDb Score  0
# 145               Regiment Diaries         9.1  1
# 140  Raja Rasoi Aur Anya Kahaniyan         9.0  1
# 33                 College Romance         8.9  1
# 24                    Black Friday         8.5  1
# 161               Taare Zameen Par         8.4  1
# 36                   Dharmakshetra         8.2  1
# 143                Rang De Basanti         8.2  1
# 122               Paan Singh Tomar         8.2  1
# 12                      Article 15         8.2  1
# 64      Gangs of Wasseypur: Part 1         8.2  1

# %%
df
# Out:
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre  \
# 0     Crime, Drama, Fantasy, Horror, Romance
# 1                                     Comedy
# 2                            Comedy, Romance
# 3                                      Drama
# 4                                      Drama
# ...                                      ...
# 9420                Comedy, Fantasy, Romance
# ...

# %%
a=[df[df['Series or Movie'] == 'Series']]

# %%
sizes = [df[df['Series or Movie'] == 'Series'].size, df[df['Series or Movie'] == 'Movie'].size]

# %%
sizes
# Out:
# [55545, 161230]

# %%
df[df['Series or Movie'] == 'Series'].size
# Out:
# 55545

# %%
df.size
# Out:
# 216775

# %%
a=df['Series or Movie'].value_counts(normalize=True)

# %%
a
# Out:
# Movie     0.743767
# Series    0.256233
# Name: Series or Movie, dtype: float64

# %%
b=a[0],a[1]

# %%
explode = (0.01, 0)
label = ['Movies','Series',]
plt.pie(b,explode,label)
plt.show()

# %%
color = ['blue', 'yellow']
label = ['Series', 'Movies']
sizes = [df[df['Series or Movie'] == 'Series'].size,df[df['Series or Movie'] == 'Movie'].size]
explode = (0.1, 0)
fig, ax = plt.subplots()
ax.pie(sizes, explode, label, color, '%2.2f%%')
ax.axis('equal')
plt.show()

# %%
hindi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5260/342900217.py in <module>
# ----> 1 hindi
#
# NameError: name 'hindi' is not defined

# %%
hindi_content

# %%
hindi_content['Series or Movie'].value_counts()

# %%
hindi_content.sort_values(by='Series or Movie',ascending=True)

# %%
hindi=hindi_content.groupby(['Title','Series or Movie']).size().reset_index()

# %%
p=hindi.sort_values(by='Series or Movie',ascending=True)

# %%
p

# %%
p.loc[p['Series or Movie']=='Movie']

# %%
q=p['Series or Movie'].value_counts(normalize=True)

# %%
s=q[0],q[1]

# %%
explode=(0.01,0)
plt.pie(s,explode,labels=['Indian Movies','Indian-Series'])

# %%
director = df.Director.str.get_dummies(',')

# %%
dirct = director.columns.str.strip().values.tolist()

# %%
dirct
